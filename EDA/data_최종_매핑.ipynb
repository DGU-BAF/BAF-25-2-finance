# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# 한글 폰트 설정
plt.rcParams['font.family'] = 'AppleGothic'

# %%
df1 = pd.read_csv('/Users/zoohunn/Desktop/비어플/비어플[금융]/datasets/data_new_products1101.csv')
df1.head()
# Out:
#    individual_id  curr_ann_amt  days_tenure date_of_birth    income  \
# 0   2.213000e+11    818.877997       1454.0    1978-06-23   22500.0
# 1   2.213001e+11    974.199182       1795.0    1950-05-30   27500.0
# 2   2.213007e+11    967.375112       4818.0    1967-07-07   42500.0
# 3   2.213016e+11    992.409561        130.0    1969-05-25  125000.0
# 4   2.213016e+11    784.633494       5896.0    1972-09-25   87500.0
#
#    has_children  length_of_residence home_market_value  age_in_years  \
# 0             1                 15.0     50000 - 74999            44
# 1             0                  2.0     50000 - 74999            72
# 2             0                 10.0     75000 - 99999            55
# 3             1                  6.0   175000 - 199999            53
# 4             1                  4.0   225000 - 249999            50
#
#    home_owner  ...  gdp_2022_11  dgs10_2022_11  cpi_2022_11 unrate_2022_11  \
# ...

# %%
df2 = pd.read_csv('/Users/zoohunn/Desktop/비어플/비어플[금융]/datasets/final_customer_data_1026.csv')
df2.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  individual_id  curr_ann_amt  \
# 0             0             0           0   2.213000e+11    818.877997
# 1             1             1           1   2.213001e+11    974.199182
# 2             2             2           2   2.213007e+11    967.375112
# 3             3             3           3   2.213016e+11    992.409561
# 4             4             4           4   2.213016e+11    784.633494
#
#    days_tenure cust_orig_date date_of_birth    income  has_children  ...  \
# 0       1454.0     2018-12-09    1978-06-23   22500.0             1  ...
# 1       1795.0     2018-01-02    1950-05-30   27500.0             0  ...
# 2       4818.0     2009-09-23    1967-07-07   42500.0             0  ...
# 3        130.0     2022-07-25    1969-05-25  125000.0             1  ...
# 4       5896.0     2006-10-11    1972-09-25   87500.0             1  ...
#
#    age_at_orig premium_to_income          policy_proxy_v2  \
# ...

# %%
df1 = df1.merge(
    df2[['individual_id', 'tax_benefit_status', 'surrender_penalty_rate', 
         'breakeven_reached', 'contact_frequency', 
         'payment_delay_history', 'contact_group']],
    on='individual_id',
    how='left'
)
df1.head()
# Out:
#    individual_id  curr_ann_amt  days_tenure date_of_birth    income  \
# 0   2.213000e+11    818.877997       1454.0    1978-06-23   22500.0
# 1   2.213001e+11    974.199182       1795.0    1950-05-30   27500.0
# 2   2.213007e+11    967.375112       4818.0    1967-07-07   42500.0
# 3   2.213016e+11    992.409561        130.0    1969-05-25  125000.0
# 4   2.213016e+11    784.633494       5896.0    1972-09-25   87500.0
#
#    has_children  length_of_residence home_market_value  age_in_years  \
# 0             1                 15.0     50000 - 74999            44
# 1             0                  2.0     50000 - 74999            72
# 2             0                 10.0     75000 - 99999            55
# 3             1                  6.0   175000 - 199999            53
# 4             1                  4.0   225000 - 249999            50
#
#    home_owner  ...  dgs10_at_orig  cpi_at_orig  unrate_at_orig sp500_at_orig  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1641992 entries, 0 to 1641991
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   individual_id           1641992 non-null  float64
#  1   curr_ann_amt            1641992 non-null  float64
#  2   days_tenure             1641992 non-null  float64
#  3   date_of_birth           1641992 non-null  object
#  4   income                  1641992 non-null  float64
#  5   has_children            1641992 non-null  int64
#  6   length_of_residence     1641992 non-null  float64
#  7   home_market_value       1641992 non-null  object
#  8   age_in_years            1641992 non-null  int64
#  9   home_owner              1641992 non-null  float64
#  10  college_degree          1641992 non-null  float64
#  11  good_credit             1641992 non-null  float64
#  12  cust_orig_year          1641992 non-null  int64
# ...

# %%
df1.to_csv('/Users/zoohunn/Desktop/비어플/비어플[금융]/datasets/final_data_1102.csv')
